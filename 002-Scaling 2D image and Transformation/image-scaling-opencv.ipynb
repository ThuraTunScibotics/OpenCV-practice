# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pwd
# Out:
# '/home/thura/Desktop/computer-vision-and-DL/CV-course1/2- 2D-scaling-Transformation'

# %%
grayImage = '/home/thura/Desktop/computer-vision-and-DL/CV-course1/2- 2D-scaling-Transformation/images/albert-einstein-gray.jpg'
colourImage = '/home/thura/Desktop/computer-vision-and-DL/CV-course1/2- 2D-scaling-Transformation/images/tulips.jpg'

# %%
imgGray = cv2.imread(grayImage, cv2.IMREAD_GRAYSCALE)
imgBGR = cv2.imread(colourImage)

# %%
plt.imshow(imgGray, cmap='gray')

# %%
plt.imshow(imgBGR[:, :, ::-1])

# %%
img_gray_resized = cv2.resize(src=imgGray, fx=1.5, fy=0.8, dsize=None)

# %%
plt.imshow(img_gray_resized, cmap='gray')
plt.xticks([])
plt.yticks([])
# Out:
# ([], [])

# %%
img_gray_resized.shape
# Out:
# (759, 1092)

# %%
imgGray.shape
# Out:
# (949, 728)

# %%
img_bgr_resized = cv2.resize(src=imgBGR, fx=0.5, fy=2, dsize=None)

# %%
plt.imshow(img_bgr_resized[:, :, ::-1])

# %% [markdown]
# ### Quiz: Can you zoom in the image to 2x using opencv?

# %%
einstein_img = cv2.imread(grayImage, cv2.IMREAD_GRAYSCALE)
einstein_img_resized = cv2.resize(src=einstein_img, fx=2, fy=2, dsize=None)
plt.imshow(einstein_img_resized, cmap='gray')

# %%
einstein_img.shape
# Out:
# (949, 728)

# %%
einstein_img_resized.shape
# Out:
# (1898, 1456)
