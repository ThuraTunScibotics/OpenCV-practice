# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import cvlib as cv
from cvlib.object_detection import draw_bbox

# %%
pwd
# Out:
# '/home/thura/Desktop/computer-vision-and-DL/CV-course1/10 - Object Detection'

# %%
img = cv2.imread('/home/thura/Desktop/computer-vision-and-DL/CV-course1/10 - Object Detection/images/p2.jpeg')

# %%
plt.imshow(img[:, :, ::-1])

# %%
bbox, conf = cv.detect_face(img)

# %%
bbox
# Out:
# [[322, 75, 357, 111],
#  [178, 93, 211, 131],
#  [12, 67, 47, 107],
#  [411, 56, 446, 96],
#  [268, 103, 297, 140],
#  [104, 37, 137, 73]]

# %%
conf
# Out:
# [0.9764316, 0.97500086, 0.9516666, 0.8955084, 0.817866, 0.8016197]

# %%
labels = []
for i in range(len(conf)):
    labels.append('person')

# %%
img2 = draw_bbox(img, bbox, labels, conf)
plt.imshow(img2[:, :, ::-1])

# %%
img3 = cv2.imread('/home/thura/Desktop/computer-vision-and-DL/CV-course1/10 - Object Detection/images/p.jpg')
bbox, labels, conf = cv.detect_common_objects(img3)

# %%
img31 = draw_bbox(img3, bbox, labels, conf)
plt.imshow(img31[:, :, ::-1])

# %%
labels
# Out:
# ['person', 'person', 'person', 'tie', 'umbrella']
