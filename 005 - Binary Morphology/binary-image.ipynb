# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pwd
# Out:
# '/home/thura/Desktop/computer-vision-and-DL/CV-course1/5 - Binary Morphology'

# %%
img_gray = plt.imread('/home/thura/Desktop/computer-vision-and-DL/CV-course1/5 - Binary Morphology/images/albert-einstein-gray.jpg')
img_binary = plt.imread('/home/thura/Desktop/computer-vision-and-DL/CV-course1/5 - Binary Morphology/images/j.png')

# %%
plt.imshow(img_binary)

# %%
np.unique(img_binary)
# Out:
# array([0., 1.], dtype=float32)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
threshold = 150
img2 = img_gray > threshold
plt.imshow(img2, cmap='gray')

# %%
plt.imshow(~(img2), cmap='gray') # Opposite situation ~ operator

# %%
np.unique(img2)
# Out:
# array([False,  True])
