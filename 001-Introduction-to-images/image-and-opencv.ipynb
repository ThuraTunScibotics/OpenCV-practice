# %% [markdown]
# ## Grayscale images in OpenCV

# %%
import cv2
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# '/home/thura/Desktop/computer-vision-and-DL/CV-course1/1-intro-to-images'

# %%
img = cv2.imread('/home/thura/Desktop/computer-vision-and-DL/CV-course1/1-intro-to-images/images/albert-einstein_gray.jpg', cv2.IMREAD_GRAYSCALE)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
img.shape
# Out:
# (949, 728)

# %%
img[23, 100] = 200

# %%
plt.imshow(img, cmap='gray')

# %%
cv2.__version__
# Out:
# '4.5.5'

# %%
cv2.imshow('Gray', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img[500:700, 500:600] = 255

# %%
cv2.imshow('Gray', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite('/home/thura/Desktop/computer-vision-and-DL/CV-course1/1-intro-to-images/images/albert-einstein-gray-opencv.jpg', img)
# Out:
# True
