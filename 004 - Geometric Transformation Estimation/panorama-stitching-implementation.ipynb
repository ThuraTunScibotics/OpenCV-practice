# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pwd
# Out:
# '/home/thura/Desktop/computer-vision-and-DL/CV-course1/4 - Geometric Transormation Estimation'

# %%
img1 = cv2.imread('/home/thura/Desktop/computer-vision-and-DL/CV-course1/4 - Geometric Transormation Estimation/images/1.jpg')
img2 = cv2.imread('/home/thura/Desktop/computer-vision-and-DL/CV-course1/4 - Geometric Transormation Estimation/images/2.jpg')
img3 = cv2.imread('/home/thura/Desktop/computer-vision-and-DL/CV-course1/4 - Geometric Transormation Estimation/images/3.jpg')

# %%
plt.subplot(131)
plt.imshow(img1[:, :, ::-1])
plt.subplot(132)
plt.imshow(img2[:, :, ::-1])
plt.subplot(133)
plt.imshow(img3[:, :, ::-1])
plt.show()

# %%
imgs = []
imgs.append(img1)
imgs.append(img2)
imgs.append(img3)

# %%
M = cv2.Stitcher.create(cv2.Stitcher_PANORAMA)
status, pano = M.stitch(imgs)

# %%
plt.imshow(pano[:, :, ::-1])
