# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
pwd
# Out:
# '/home/thura/Desktop/computer-vision-and-DL/CV-course1/7 - Canny Edge Detector'

# %%
imgPath = '/home/thura/Desktop/computer-vision-and-DL/CV-course1/7 - Canny Edge Detector/images/cm.jpg'
img = plt.imread(imgPath)

# %%
plt.imshow(img, cmap='gray')

# %%
Edge = cv2.Canny(img, 100, 250)

# %%
plt.subplot(121)
plt.imshow(img, cmap='gray')
plt.axis('off')
plt.subplot(122)
plt.imshow(Edge, cmap='gray')
plt.axis('off')
plt.show()
